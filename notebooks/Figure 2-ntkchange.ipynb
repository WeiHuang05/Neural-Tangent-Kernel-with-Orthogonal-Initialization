# %% [markdown]
# # Figures 2
#
# Generate figures descrive the changes of weights, empirical ntk with Gaussian and orthogonal initialzation.

# %% [markdown]
# ## Setup

# %%
from __future__ import print_function
import os, sys
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("paper")
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['text.usetex'] = True
plt.rcParams['text.latex.unicode'] = True
plt.rcParams['image.cmap'] = 'viridis'

sys.path.insert(0, '../')

# Output figure directory
figure_dir = "../writeup/figures"
results_dir = "../results"

# %% [markdown]
# ### Gaussian weights

# %%
import csv   
import numpy as np

ensemble_size = 5
number_width = 9

gau_ntk = np.zeros((number_width,2*ensemble_size)); gau_w1 = np.zeros((number_width,2*ensemble_size))
gau_w2 = np.zeros((number_width,2*ensemble_size)); gau_w3 = np.zeros((number_width,2*ensemble_size))
gau_w4 = np.zeros((number_width,2*ensemble_size))


with open('../data/ntk_change/gaussian_ntkc_1.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        ntk_temp1 = []
        for row in spamreader:
            ntk_temp1 = np.append(ntk_temp1,float(row[0]))
            
with open('../data/ntk_change/gaussian_ntkc_2.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        ntk_temp2 = []
        for row in spamreader:
            ntk_temp2 = np.append(ntk_temp2,float(row[0]))
            
with open('../data/ntk_change/gaussian_ntkc_3.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        ntk_temp3 = []
        for row in spamreader:
            ntk_temp3 = np.append(ntk_temp3,float(row[0]))            
            
            
with open('../data/ntk_change/gaussian_wch1_1.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w1_temp1 = []
        for row in spamreader:
            w1_temp1 = np.append(w1_temp1,float(row[0]))
            
with open('../data/ntk_change/gaussian_wch1_2.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w1_temp2 = []
        for row in spamreader:
            w1_temp2 = np.append(w1_temp2,float(row[0]))
            
with open('../data/ntk_change/gaussian_wch1_3.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w1_temp3 = []
        for row in spamreader:
            w1_temp3 = np.append(w1_temp3,float(row[0]))            
            
with open('../data/ntk_change/gaussian_wch2_1.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w2_temp1 = []
        for row in spamreader:
            w2_temp1 = np.append(w2_temp1,float(row[0]))
            
with open('../data/ntk_change/gaussian_wch2_2.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w2_temp2 = []
        for row in spamreader:
            w2_temp2 = np.append(w2_temp2,float(row[0]))
            
with open('../data/ntk_change/gaussian_wch2_3.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w2_temp3 = []
        for row in spamreader:
            w2_temp3 = np.append(w2_temp3,float(row[0]))            
            
            
with open('../data/ntk_change/gaussian_wch3_1.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w3_temp1 = []
        for row in spamreader:
            w3_temp1 = np.append(w3_temp1,float(row[0]))      
            
with open('../data/ntk_change/gaussian_wch3_2.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w3_temp2 = []
        for row in spamreader:
            w3_temp2 = np.append(w3_temp2,float(row[0]))    
            
with open('../data/ntk_change/gaussian_wch3_3.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w3_temp3 = []
        for row in spamreader:
            w3_temp3 = np.append(w3_temp3,float(row[0]))            
            
with open('../data/ntk_change/gaussian_wch4_1.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w4_temp1 = []
        for row in spamreader:
            w4_temp1 = np.append(w4_temp1,float(row[0]))   
            
with open('../data/ntk_change/gaussian_wch4_2.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w4_temp2 = []
        for row in spamreader:
            w4_temp2 = np.append(w4_temp2,float(row[0]))   

with open('../data/ntk_change/gaussian_wch4_3.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w4_temp3 = []
        for row in spamreader:
            w4_temp3 = np.append(w4_temp3,float(row[0]))  
              
gau_ntk = np.concatenate((ntk_temp1.reshape(number_width,ensemble_size),ntk_temp2.reshape(number_width,ensemble_size), ntk_temp3.reshape(number_width,ensemble_size)),axis=1) 
gau_w1  = np.concatenate((w1_temp1.reshape(number_width,ensemble_size),w1_temp2.reshape(number_width,ensemble_size),w1_temp3.reshape(number_width,ensemble_size)),axis=1) 
gau_w2  = np.concatenate((w2_temp1.reshape(number_width,ensemble_size),w2_temp2.reshape(number_width,ensemble_size),w2_temp3.reshape(number_width,ensemble_size)),axis=1) 
gau_w3  = np.concatenate((w3_temp1.reshape(number_width,ensemble_size),w3_temp2.reshape(number_width,ensemble_size),w3_temp3.reshape(number_width,ensemble_size)),axis=1) 
gau_w4  = np.concatenate((w4_temp1.reshape(number_width,ensemble_size),w4_temp2.reshape(number_width,ensemble_size),w4_temp3.reshape(number_width,ensemble_size)),axis=1)

# %% [markdown]
# ### Orthogonal weights

# %%
import csv   
import numpy as np

ensemble_size = 5
number_width = 9

ort_ntk = np.zeros((number_width,2*ensemble_size)); ort_w1 = np.zeros((number_width,2*ensemble_size))
ort_w2 = np.zeros((number_width,2*ensemble_size)); ort_w3 = np.zeros((number_width,2*ensemble_size))
ort_w4 = np.zeros((number_width,2*ensemble_size))


with open('../data/ntk_change/orthogonal_ntkc_1.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        ntk_temp1 = []
        for row in spamreader:
            ntk_temp1 = np.append(ntk_temp1,float(row[0]))
            
with open('../data/ntk_change/orthogonal_ntkc_2.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        ntk_temp2 = []
        for row in spamreader:
            ntk_temp2 = np.append(ntk_temp2,float(row[0]))
            
with open('../data/ntk_change/orthogonal_ntkc_3.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        ntk_temp3 = []
        for row in spamreader:
            ntk_temp3 = np.append(ntk_temp3,float(row[0]))            
            
            
with open('../data/ntk_change/orthogonal_wch1_1.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w1_temp1 = []
        for row in spamreader:
            w1_temp1 = np.append(w1_temp1,float(row[0]))
            
with open('../data/ntk_change/orthogonal_wch1_2.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w1_temp2 = []
        for row in spamreader:
            w1_temp2 = np.append(w1_temp2,float(row[0]))
            
with open('../data/ntk_change/orthogonal_wch1_3.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w1_temp3 = []
        for row in spamreader:
            w1_temp3 = np.append(w1_temp3,float(row[0]))            
            
            
with open('../data/ntk_change/orthogonal_wch2_1.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w2_temp1 = []
        for row in spamreader:
            w2_temp1 = np.append(w2_temp1,float(row[0]))
            
with open('../data/ntk_change/orthogonal_wch2_2.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w2_temp2 = []
        for row in spamreader:
            w2_temp2 = np.append(w2_temp2,float(row[0]))
            
with open('../data/ntk_change/orthogonal_wch2_3.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w2_temp3 = []
        for row in spamreader:
            w2_temp3 = np.append(w2_temp3,float(row[0]))            
            
            
with open('../data/ntk_change/orthogonal_wch3_1.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w3_temp1 = []
        for row in spamreader:
            w3_temp1 = np.append(w3_temp1,float(row[0]))      
            
with open('../data/ntk_change/orthogonal_wch3_2.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w3_temp2 = []
        for row in spamreader:
            w3_temp2 = np.append(w3_temp2,float(row[0]))  
            
with open('../data/ntk_change/orthogonal_wch3_3.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w3_temp3 = []
        for row in spamreader:
            w3_temp3 = np.append(w3_temp3,float(row[0]))             
            
with open('../data/ntk_change/orthogonal_wch4_1.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w4_temp1 = []
        for row in spamreader:
            w4_temp1 = np.append(w4_temp1,float(row[0]))   
            
with open('../data/ntk_change/orthogonal_wch4_2.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w4_temp2 = []
        for row in spamreader:
            w4_temp2 = np.append(w4_temp2,float(row[0]))   
            
with open('../data/ntk_change/orthogonal_wch4_3.csv' , newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ')
        w4_temp3 = []
        for row in spamreader:
            w4_temp3 = np.append(w4_temp3,float(row[0]))            
              
ort_ntk = np.concatenate((ntk_temp1.reshape(number_width,ensemble_size),ntk_temp2.reshape(number_width,ensemble_size),ntk_temp3.reshape(number_width,ensemble_size)),axis=1) 
ort_w1  = np.concatenate((w1_temp1.reshape(number_width,ensemble_size),w1_temp2.reshape(number_width,ensemble_size),w1_temp3.reshape(number_width,ensemble_size)),axis=1) 
ort_w2  = np.concatenate((w2_temp1.reshape(number_width,ensemble_size),w2_temp2.reshape(number_width,ensemble_size),w2_temp3.reshape(number_width,ensemble_size)),axis=1) 
ort_w3  = np.concatenate((w3_temp1.reshape(number_width,ensemble_size),w3_temp2.reshape(number_width,ensemble_size),w3_temp3.reshape(number_width,ensemble_size)),axis=1) 
ort_w4  = np.concatenate((w4_temp1.reshape(number_width,ensemble_size),w4_temp2.reshape(number_width,ensemble_size),w4_temp3.reshape(number_width,ensemble_size)),axis=1)

# %% [markdown]
# # Figure 2:  Changes of weights and empirical NTK
# Changes of weights, empirical NTK on a three hidden layer Erf Network. Solid lines correspond to empirical simulation and dotted lines are theoretical predictions, i.e. black dotted lines are $1/\sqrt{n}$ while red dotted lines are $1/n$. (a) weight changes on Gaussian initialized network. (b) weight changes on the orthogonal initialized network. (c) NTK changes on both Gaussian and orthogonal networks.

# %%
import matplotlib
plt.figure(figsize=(20,5))
gs = plt.GridSpec(1,3)
matplotlib.rc('xtick',labelsize=15)
matplotlib.rc('ytick',labelsize=15)
x = np.arange(number_width)
import seaborn as sns
sns.set_style("darkgrid", {"axes.facecolor":".95"})

ax0 = plt.subplot((gs[0,0]))
plt.errorbar(2**(x+4),np.mean(gau_w1,1),np.var(gau_w1,1),lw=2,color='blue', alpha=0.5,label='layer 1')
plt.errorbar(2**(x+4),np.mean(gau_w2,1),np.var(gau_w2,1),lw=2,color='brown',  alpha=0.5,label='layer 2')
plt.errorbar(2**(x+4),np.mean(gau_w3,1),np.var(gau_w3,1),lw=2,color='green', alpha=0.5, label='layer 3')
plt.errorbar(2**(x+4),np.mean(gau_w4,1),np.var(gau_w4,1),lw=2,color='grey', alpha=0.5, label='layer 4')

plt.plot(2**(x+4),0.125*(2**(x+4))**(-0.5),color = 'black',ls='--',lw=2, label =r'$1/\sqrt{n}$')
plt.plot(2**(x+4),0.67*(2**(x+4))**(-0.5),color = 'black',ls='--',lw=2)
plt.plot(2**(x+4),2.80*(2**(x+4))**(-1.0),color = 'red',ls='--',lw=2, label =r'$1/n$')
plt.plot(2**(x+4),2.40*(2**(x+4))**(-1.0),color = 'red',ls='--',lw=2)

ax0.set_xscale("log"); ax0.set_yscale("log")
plt.legend(fontsize=12); plt.xlabel('$n$',fontsize=15); plt.ylabel('$||W_T^l - W_0^l||_F/||W_0^l||_F$',fontsize=15)
plt.title('(a) Gaussian initialization',fontsize=15)

ax1 = plt.subplot((gs[0,1]))

plt.errorbar(2**(x+4),np.mean(ort_w1,1),np.var(ort_w1,1),lw=2,alpha=0.5,color='blue')
plt.errorbar(2**(x+4),np.mean(ort_w2,1),np.var(ort_w2,1),lw=2,alpha=0.5,color='brown')
plt.errorbar(2**(x+4),np.mean(ort_w3,1),np.var(ort_w3,1),lw=2,alpha=0.5,color='green')
plt.errorbar(2**(x+4),np.mean(ort_w4,1),np.var(ort_w4,1),lw=2,alpha=0.5,color='grey')

plt.plot(2**(x+4),0.125*(2**(x+4))**(-0.5),color = 'black',ls='--',lw=2)
plt.plot(2**(x+4),0.665*(2**(x+4))**(-0.5),color = 'black',ls='--',lw=2)
plt.plot(2**(x+4),2.80*(2**(x+4))**(-1.0),color = 'red',ls='--',lw=2)
plt.plot(2**(x+4),2.40*(2**(x+4))**(-1.0),color = 'red',ls='--',lw=2)

plt.xlabel('$n$',fontsize=15); ax1.set_xscale("log"); ax1.set_yscale("log")
plt.title('(b) Orthogonal initialization',fontsize=15)

ax2 = plt.subplot((gs[0,2]))

plt.errorbar(2**(x+4),np.mean(gau_ntk,1),np.var(gau_ntk,1),lw=2,color='blue',label ='Gaussian')
plt.errorbar(2**(x+4),np.mean(ort_ntk,1),np.var(ort_ntk,1),lw=2,color='green',label ='Orthogonal')

plt.plot(2**(x+4),3.5*(2**(x+4))**(-0.5),color = 'black',ls='--',lw=2, label =r'$1/\sqrt{n}$')
plt.plot(2**(x+4),12.0*(2**(x+4))**(-1.0),color = 'red',ls='--',lw=2, label =r'$1/n$')

ax2.set_xscale("log")
ax2.set_yscale("log")
plt.legend(fontsize=12);
plt.xlabel('$n$',fontsize=15); plt.ylabel('$||\hat \Theta_T^{(n)} -\hat \Theta_0^{(n)}||_F/||\hat \Theta_0^{(n)}||_F$',fontsize=15)
plt.title('(c) NTK change',fontsize=15)

plt.savefig("fig2_ntkchange.pdf", bbox_inches='tight')
